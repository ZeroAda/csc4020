# %%
from sklearn import preprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import AdaBoostRegressor
import seaborn as sns
from sklearn.model_selection import ParameterGrid
import math

# %%
data = pd.read_csv("Carseats.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
# Explore data
print(data["Sales"].describe())
plt.figure(figsize=(9,8))
sns.distplot(data['Sales'], color='g', bins=100, hist_kws={'alpha': 0.4})
# Out:
# count    400.000000
# mean       7.496325
# std        2.824115
# min        0.000000
# 25%        5.390000
# 50%        7.490000
# 75%        9.320000
# max       16.270000
# Name: Sales, dtype: float64
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data["ShelveLoc"] = data["ShelveLoc"].astype('category')
data.dtypes
data["ShelveLoc"] = data["ShelveLoc"].cat.codes
data.head()

data["Urban"] = data["Urban"].astype('category')
data.dtypes
data["Urban"] = data["Urban"].cat.codes
data.head()


data["US"] = data["US"].astype('category')
data.dtypes
data["US"] = data["US"].cat.codes
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120          0   42
# 1  11.22        111      48           16         260     83          1   65
# 2  10.06        113      35           10         269     80          2   59
# 3   7.40        117     100            4         466     97          2   55
# 4   4.15        141      64            3         340    128          0   38
#
#    Education  Urban  US
# 0         17      1   1
# 1         10      1   1
# 2         12      1   1
# 3         14      1   1
# 4         13      1   0

# %%
d_x = data.iloc[:,1:]
d_y = data.iloc[:,0]

# %%
d_x.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<AxesSubplot:title={'center':'CompPrice'}>,
#         <AxesSubplot:title={'center':'Income'}>,
#         <AxesSubplot:title={'center':'Advertising'}>],
#        [<AxesSubplot:title={'center':'Population'}>,
#         <AxesSubplot:title={'center':'Price'}>,
#         <AxesSubplot:title={'center':'ShelveLoc'}>],
#        [<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Education'}>,
#         <AxesSubplot:title={'center':'Urban'}>],
#        [<AxesSubplot:title={'center':'US'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
data_corr = data.corr()['Sales'][1:] # -1 because the latest row is SalePrice
golden_features_list = data_corr[abs(data_corr) > 0.1].sort_values(ascending=False)
print("There is {} strongly correlated values with SalePrice:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 6 strongly correlated values with SalePrice:
# Advertising    0.269507
# US             0.177093
# ShelveLoc      0.157470
# Income         0.151951
# Age           -0.231815
# Price         -0.444951
# Name: Sales, dtype: float64

# %%
for i in range(1, len(data.columns), 5):
    sns.pairplot(data=data,
                x_vars=data.columns[i:i+5],
                y_vars=['Sales'])

# %%
x_train = d_x[:300]
y_train = d_y[:300]

x_test = d_x[300:]
y_test = d_y[300:]
feature = np.array(x_train.columns)
target = y_train.name
print(feature)
print(target)
# Out:
# ['CompPrice' 'Income' 'Advertising' 'Population' 'Price' 'ShelveLoc' 'Age'
#  'Education' 'Urban' 'US']
# Sales

# %%
# Decision Tree
# 1.parameter list
# 1.1 max depth
treelist = []
dt0 = DecisionTreeRegressor()
dt1 = DecisionTreeRegressor(max_depth=10)
x_train = d_x[:300]
y_train = d_y[:300]

x_test = d_x[300:]
y_test = d_y[300:]
feature = np.array(x_train.columns)
target = y_train.name
print(feature)
print(target)

dt2 = DecisionTreeRegressor(max_depth=5)
dt3 = DecisionTreeRegressor(max_depth=2)

dt0.fit(x_train,y_train)
dt1.fit(x_train,y_train)
dt2.fit(x_train,y_train)
dt3.fit(x_train,y_train)
# 1.2. least node size
dt4 = DecisionTreeRegressor(min_samples_leaf=10)
dt5 = DecisionTreeRegressor(min_samples_leaf=20)
dt6 = DecisionTreeRegressor(min_samples_leaf=30)
dt4.fit(x_train,y_train)
dt5.fit(x_train,y_train)
dt6.fit(x_train,y_train)

# 2.visualize deicision tree
fig = plt.figure(figsize=(25,20))
_ = plot_tree(dt0, 
                   feature_names=feature,  
                   class_names=target,
                   filled=True)
plt.title("Decision Tree Regression default")

fig = plt.figure(figsize=(25,20))
_ = plot_tree(dt1, 
                   feature_names=feature,  
                   class_names=target,
                   filled=True)
plt.title("Decision Tree Regression max=10")

fig = plt.figure(figsize=(25,20))
_ = plot_tree(dt2, 
                   feature_names=feature,  
                   class_names=target,
                   filled=True)
plt.title("Decision Tree Regression max=5")


fig = plt.figure(figsize=(25,20))
_ = plot_tree(dt3, 
                   feature_names=feature,  
                   class_names=target,
                   filled=True)
plt.title("Decision Tree Regression max=2")


fig = plt.figure(figsize=(25,20))
_ = plot_tree(dt4, 
                   feature_names=feature,  
                   class_names=target,
                   filled=True)
plt.title("Decision Tree Regression minimunm leaf node=10")

fig = plt.figure(figsize=(25,20))
_ = plot_tree(dt5, 
                   feature_names=feature,  
                   class_names=target,
                   filled=True)
plt.title("Decision Tree Regression minimunm leaf node=10")

fig = plt.figure(figsize=(25,20))
_ = plot_tree(dt6, 
                   feature_names=feature,  
                   class_names=target,
                   filled=True)
plt.title("Decision Tree Regression minimunm leaf node=10")

treelist.append(dt0)
treelist.append(dt1)
treelist.append(dt2)
treelist.append(dt3)
treelist.append(dt4)
treelist.append(dt5)
treelist.append(dt6)

# %%
# 3. Prediction

print("default")
print(dt0.score(x_test,y_test))

print("max_depth=10 ")
print(dt1.score(x_test,y_test))
print("max_depth=5 ")
print(dt2.score(x_test,y_test))
print("max_depth=2 ")
print(dt3.score(x_test,y_test))

print("minimum leaf node=10")
print(dt4.score(x_test,y_test))

print("minimum leaf node=20")
print(dt5.score(x_test,y_test))

print("minimum leaf node=30")
print(dt6.score(x_test,y_test))
# Out:
# default
# 0.1346570770260216
# max_depth=10
# 0.20849845634976938
# max_depth=5
# 0.35986617485230377
# max_depth=2
# 0.30570488224032744
# minimum leaf node=10
# 0.4182351643452057
# minimum leaf node=20
# 0.3962816362344178
# minimum leaf node=30
# 0.2976227425381084

# %%
# 4. Feature importance

for tree in treelist:
    
    importances = tree.feature_importances_
    std = np.std([tree.feature_importances_],
             axis=0)
    indices = np.argsort(importances)

# Plot the feature importances of the forest
    plt.figure()
    plt.title("Feature importances")
    plt.barh(range(len(feature)), importances[indices],
       color="r", xerr=std[indices], align="center")
    plt.yticks(range(x_train.shape[1]), feature[indices])
    plt.ylim([-1, len(feature)])
    plt.show()

# %%
# Bagging
# 1. parameter list
n_learner_list = [5,10,20]
max_depth_list = [2,5,10,20]
for depth in max_depth_list:
    base_learner = DecisionTreeRegressor(max_depth=depth)
    for n in n_learner_list:
        bg = BaggingRegressor(base_estimator=base_learner,n_estimators=n,oob_score=True,max_features=10)
        bg.fit(x_train,y_train)
        print("{} learner with {} max depth".format(n, depth))
        print(bg.score(x_test,y_test))
        print(bg.oob_score_)
# Out:
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_bagging.py:1069: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_bagging.py:1069: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# 5 learner with 2 max depth
# 0.4157486161538817
# -0.31262641554444737
# 10 learner with 2 max depth
# 0.4164791030252316
# 0.3213037969738941
# 20 learner with 2 max depth
# 0.4058039103315957
# 0.3379861732161915
# 5 learner with 5 max depth
# 0.5685619736421529
# -0.5077276042006167
# 10 learner with 5 max depth
# 0.5916870929934834
# 0.38473511754534073
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_bagging.py:1069: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_bagging.py:1069: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# 20 learner with 5 max depth
# 0.6522677853239306
# 0.6031204602346318
# 5 learner with 10 max depth
# 0.6288950091797063
# -0.5403153829924447
# 10 learner with 10 max depth
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_bagging.py:1069: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_bagging.py:1069: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# 0.5949605544357579
# 0.4186537209847113
# 20 learner with 10 max depth
# 0.7034105846478016
# 0.6072819001105741
# 5 learner with 20 max depth
# 0.5781279006551208
# -0.28286245040720637
# 10 learner with 20 max depth
# 0.6419730203848693
# 0.4642514211487059
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_bagging.py:1069: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_bagging.py:1069: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# 20 learner with 20 max depth
# 0.6286556826440051
# 0.636331075617471

# %%
# Random forest
n_learner_list = [5,10,20]
max_depth_list = [2,5,10,20]
max_features_list = ['auto', 'sqrt', 'log2']
m = {'auto':len(feature), 'sqrt':math.sqrt(len(feature)), 'log2':math.log2(len((feature)))}
for n in n_learner_list:
    for depth in max_depth_list:
        for mtry in max_features_list:
            rf = RandomForestRegressor(n_estimators=n,max_depth=depth,oob_score=True,max_features=mtry)
            rf.fit(x_train,y_train)
            
            print("{} learner with {} max depth {} max feature".format(n, depth, m[mtry]))
            print(rf.score(x_test,y_test))
            print(rf.oob_score_)
# Out:
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# 5 learner with 2 max depth 10 max feature
# 0.4036085133807935
# -0.5516564814669889
# 5 learner with 2 max depth 3.1622776601683795 max feature
# 0.21298922351781435
# -0.21629034293594884
# 5 learner with 2 max depth 3.321928094887362 max feature
# 0.23869898397058076
# -0.41618040124960665
# 5 learner with 5 max depth 10 max feature
# 0.6174673865891128
# -0.17389088707808265
# 5 learner with 5 max depth 3.1622776601683795 max feature
# 0.3858975118277299
# -0.43851129293778035
# 5 learner with 5 max depth 3.321928094887362 max feature
# 0.5156760667397553
# -0.27349773406249134
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# 5 learner with 10 max depth 10 max feature
# 0.5830006191644969
# -0.3218670884183734
# 5 learner with 10 max depth 3.1622776601683795 max feature
# 0.5168092060810671
# -0.39740086568857436
# 5 learner with 10 max depth 3.321928094887362 max feature
# 0.4597873571956249
# -0.5652132445112998
# 5 learner with 20 max depth 10 max feature
# 0.5951903858521417
# -0.23756816681738102
# 5 learner with 20 max depth 3.1622776601683795 max feature
# 0.4088222090696517
# -0.4977577729690901
# 5 learner with 20 max depth 3.321928094887362 max feature
# 0.5855836643046402
# -0.5598201330392625
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# 10 learner with 2 max depth 10 max feature
# 0.38726852966949865
# 0.28979081621743363
# 10 learner with 2 max depth 3.1622776601683795 max feature
# 0.27441689274084236
# 0.14137378850719884
# 10 learner with 2 max depth 3.321928094887362 max feature
# 0.26519450847843107
# 0.03053536484917352
# 10 learner with 5 max depth 10 max feature
# 0.5819216598410235
# 0.46654277624579676
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# 10 learner with 5 max depth 3.1622776601683795 max feature
# 0.4886809878395093
# 0.22018234012275328
# 10 learner with 5 max depth 3.321928094887362 max feature
# 0.531510026761494
# 0.32194412090603497
# 10 learner with 10 max depth 10 max feature
# 0.631704109437518
# 0.513949364471035
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# 10 learner with 10 max depth 3.1622776601683795 max feature
# 0.5462838618792152
# 0.41361484606256405
# 10 learner with 10 max depth 3.321928094887362 max feature
# 0.5511813331731862
# 0.38321656609068566
# 10 learner with 20 max depth 10 max feature
# 0.6055803344529025
# 0.4899204606395262
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# 10 learner with 20 max depth 3.1622776601683795 max feature
# 0.5450605973128311
# 0.3151353832288982
# 10 learner with 20 max depth 3.321928094887362 max feature
# 0.6418512562432342
# 0.42980539350727787
# 20 learner with 2 max depth 10 max feature
# 0.4064536916657696
# 0.3617062088639511
# 20 learner with 2 max depth 3.1622776601683795 max feature
# 0.3023602298754292
# 0.2962054001443384
# 20 learner with 2 max depth 3.321928094887362 max feature
# 0.24596250524002805
# 0.1784086909158249
# 20 learner with 5 max depth 10 max feature
# 0.6493987506065799
# 0.5857519802434188
# 20 learner with 5 max depth 3.1622776601683795 max feature
# 0.5767011217630746
# 0.4033173589257354
# C:\Users\adaqu\anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_forest.py:833: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# 20 learner with 5 max depth 3.321928094887362 max feature
# 0.49892811434221773
# 0.45614202449274843
# 20 learner with 10 max depth 10 max feature
# 0.6414644345990228
# 0.6110483017619668
# 20 learner with 10 max depth 3.1622776601683795 max feature
# 0.5996610076443625
# 0.5057723837153227
# 20 learner with 10 max depth 3.321928094887362 max feature
# 0.5527786689851437
# 0.5508708710719171
# 20 learner with 20 max depth 10 max feature
# 0.6943991728873682
# 0.6526434377330111
# 20 learner with 20 max depth 3.1622776601683795 max feature
# 0.5757583453207713
# 0.5378016893725137
# 20 learner with 20 max depth 3.321928094887362 max feature
# 0.5411826805212483
# 0.48037131942406075

# %%
# AdaBoost
n_learner_list = [5,10,20,30,40,50]
max_depth_list = [2,5,10,20]
learning_rate_list = [0.1,0.5,1]

# learning rate
for n in n_learner_list:
    for depth in max_depth_list:
        base_learner = DecisionTreeRegressor(max_depth=depth)
        for learning_rate in learning_rate_list:
            
            ada = AdaBoostRegressor(base_estimator=base_learner,learning_rate=learning_rate,n_estimators=n,loss='square')
            ada.fit(x_train[90:],y_train[90:])
            
            # out of bag estimation
            print("oob")
            print(ada.score(x_train[:90],y_train[:90]))
            # learning rate is alpha
            print("{} learner with {} max depth {} learning rate".format(n, depth, learning_rate))
            print(ada.score(x_test,y_test))
# Out:
# oob
# 0.1747827928008745
# 5 learner with 2 max depth 0.1 learning rate
# 0.21185666417598914
# oob
# 0.23707332625389643
# 5 learner with 2 max depth 0.5 learning rate
# 0.2976695503716965
# oob
# 0.40823705900867235
# 5 learner with 2 max depth 1 learning rate
# 0.4330511888700793
# oob
# 0.5112817520543442
# 5 learner with 5 max depth 0.1 learning rate
# 0.47343240456994773
# oob
# 0.5163685295981428
# 5 learner with 5 max depth 0.5 learning rate
# 0.43601191400992034
# oob
# 0.4438803309349416
# 5 learner with 5 max depth 1 learning rate
# 0.37219710671832984
# oob
# 0.5528895639057361
# 5 learner with 10 max depth 0.1 learning rate
# 0.46190589198102094
# oob
# 0.5374838386766215
# 5 learner with 10 max depth 0.5 learning rate
# 0.4233575792346088
# oob
# 0.5689536366199345
# 5 learner with 10 max depth 1 learning rate
# 0.3567714878621344
# oob
# 0.5193901840751721
# 5 learner with 20 max depth 0.1 learning rate
# 0.5652318018733358
# oob
# 0.42045431044202763
# 5 learner with 20 max depth 0.5 learning rate
# 0.5481072423926736
# oob
# 0.42642981199777774
# 5 learner with 20 max depth 1 learning rate
# 0.44902920763513066
# oob
# 0.35257400649372217
# 10 learner with 2 max depth 0.1 learning rate
# 0.404533587164281
# oob
# 0.24434045180880826
# 10 learner with 2 max depth 0.5 learning rate
# 0.2775678906153767
# oob
# 0.2911479152095925
# 10 learner with 2 max depth 1 learning rate
# 0.3239334080890114
# oob
# 0.5653820100963809
# 10 learner with 5 max depth 0.1 learning rate
# 0.5324348341013311
# oob
# 0.5658125141565469
# 10 learner with 5 max depth 0.5 learning rate
# 0.5055001562694248
# oob
# 0.5225203406876257
# 10 learner with 5 max depth 1 learning rate
# 0.4597653618309898
# oob
# 0.5756910416946585
# 10 learner with 10 max depth 0.1 learning rate
# 0.5550662481054633
# oob
# 0.5351556911473898
# 10 learner with 10 max depth 0.5 learning rate
# 0.5106625867673138
# oob
# 0.5777589213833692
# 10 learner with 10 max depth 1 learning rate
# 0.5922174402910836
# oob
# 0.5745215523758334
# 10 learner with 20 max depth 0.1 learning rate
# 0.5004393258046249
# oob
# 0.5679044985597316
# 10 learner with 20 max depth 0.5 learning rate
# 0.4351757738382782
# oob
# 0.5045932546874066
# 10 learner with 20 max depth 1 learning rate
# 0.46604576821325183
# oob
# 0.33371033331925903
# 20 learner with 2 max depth 0.1 learning rate
# 0.3479605440432102
# oob
# 0.3587620219991694
# 20 learner with 2 max depth 0.5 learning rate
# 0.3802559486309217
# oob
# 0.4078645686659509
# 20 learner with 2 max depth 1 learning rate
# 0.4257841377974062
# oob
# 0.5853095774018484
# 20 learner with 5 max depth 0.1 learning rate
# 0.470586591146105
# oob
# 0.58005292594345
# 20 learner with 5 max depth 0.5 learning rate
# 0.5670426176279875
# oob
# 0.5934190178214072
# 20 learner with 5 max depth 1 learning rate
# 0.5832835299326213
# oob
# 0.5694986498632455
# 20 learner with 10 max depth 0.1 learning rate
# 0.5228601112859275
# oob
# 0.6067981144155288
# 20 learner with 10 max depth 0.5 learning rate
# 0.5353962133128062
# oob
# 0.6045413283501218
# 20 learner with 10 max depth 1 learning rate
# 0.5968138839959936
# oob
# 0.5923521218950643
# 20 learner with 20 max depth 0.1 learning rate
# 0.5654504402383822
# oob
# 0.6008149724525144
# 20 learner with 20 max depth 0.5 learning rate
# 0.5678120250424792
# oob
# 0.5732227207816842
# 20 learner with 20 max depth 1 learning rate
# 0.5487842819675273
# oob
# 0.3042367871070778
# 30 learner with 2 max depth 0.1 learning rate
# 0.3149979311888963
# oob
# 0.34337681026421096
# 30 learner with 2 max depth 0.5 learning rate
# 0.36476541434190646
# oob
# 0.4172731719803995
# 30 learner with 2 max depth 1 learning rate
# 0.4488715711516895
# oob
# 0.611776659685166
# 30 learner with 5 max depth 0.1 learning rate
# 0.597477646454101
# oob
# 0.5839693419718037
# 30 learner with 5 max depth 0.5 learning rate
# 0.5279863183391883
# oob
# 0.6045891553624835
# 30 learner with 5 max depth 1 learning rate
# 0.5802718276119989
# oob
# 0.6059875370791235
# 30 learner with 10 max depth 0.1 learning rate
# 0.5925209643707083
# oob
# 0.5833187857979008
# 30 learner with 10 max depth 0.5 learning rate
# 0.5416986608323644
# oob
# 0.6137374857501828
# 30 learner with 10 max depth 1 learning rate
# 0.6147238964395838
# oob
# 0.5618062134948649
# 30 learner with 20 max depth 0.1 learning rate
# 0.5557473065654629
# oob
# 0.6219230640778601
# 30 learner with 20 max depth 0.5 learning rate
# 0.6109153376481915
# oob
# 0.6408380153111822
# 30 learner with 20 max depth 1 learning rate
# 0.5459695770735515
# oob
# 0.2830702203137063
# 40 learner with 2 max depth 0.1 learning rate
# 0.2912888530372638
# oob
# 0.39428064591118195
# 40 learner with 2 max depth 0.5 learning rate
# 0.43880200899977806
# oob
# 0.5199450208845252
# 40 learner with 2 max depth 1 learning rate
# 0.5847672465101497
# oob
# 0.5685280978365642
# 40 learner with 5 max depth 0.1 learning rate
# 0.5649037623418576
# oob
# 0.6039980614255178
# 40 learner with 5 max depth 0.5 learning rate
# 0.5680786796415163
# oob
# 0.6259145985790007
# 40 learner with 5 max depth 1 learning rate
# 0.5401173992930928
# oob
# 0.6081427507899162
# 40 learner with 10 max depth 0.1 learning rate
# 0.5421903579935666
# oob
# 0.603940672865399
# 40 learner with 10 max depth 0.5 learning rate
# 0.5804317584745134
# oob
# 0.6399460081847541
# 40 learner with 10 max depth 1 learning rate
# 0.6072403512989482
# oob
# 0.6151501998984055
# 40 learner with 20 max depth 0.1 learning rate
# 0.5742973723428679
# oob
# 0.6165759714425105
# 40 learner with 20 max depth 0.5 learning rate
# 0.5801507016157945
# oob
# 0.5890060746832211
# 40 learner with 20 max depth 1 learning rate
# 0.5987735148202167
# oob
# 0.2877166973377937
# 50 learner with 2 max depth 0.1 learning rate
# 0.3103830304055868
# oob
# 0.36842287612167945
# 50 learner with 2 max depth 0.5 learning rate
# 0.4218729973076337
# oob
# 0.4656402535785986
# 50 learner with 2 max depth 1 learning rate
# 0.4986666258885142
# oob
# 0.6088955409047921
# 50 learner with 5 max depth 0.1 learning rate
# 0.5695722061961721
# oob
# 0.6110767347035103
# 50 learner with 5 max depth 0.5 learning rate
# 0.5922152248530694
# oob
# 0.6271582449192934
# 50 learner with 5 max depth 1 learning rate
# 0.6166659791664824
# oob
# 0.6444236703175537
# 50 learner with 10 max depth 0.1 learning rate
# 0.5478250220657448
# oob
# 0.6178539327530337
# 50 learner with 10 max depth 0.5 learning rate
# 0.6089897971237919
# oob
# 0.6047005614176425
# 50 learner with 10 max depth 1 learning rate
# 0.5766062157622376
# oob
# 0.6182506800920156
# 50 learner with 20 max depth 0.1 learning rate
# 0.5836077227210932
# oob
# 0.6112780820797985
# 50 learner with 20 max depth 0.5 learning rate
# 0.6127713872471179
# oob
# 0.6005983881839172
# 50 learner with 20 max depth 1 learning rate
# 0.5688905617599092

# %%
# nextwork: 
# 1. for each model, find the best parameter using out of bag data
# 2. for each model, plot train/error comparison
# 3. plot the feature importance in different model --- see the relationship between correlation and this
# 4. compare performace of all models using score(mean of square error)


# question: least square loss for adaboost and learning rate?
